# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianValencia08/ProyectoDatosAlgoritmos/blob/main/imagen_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# %%
uploades = files.upload()
# Out:
#      <input type="file" id="files-12c267c6-0d03-41ae-bea3-7c051c6bff0f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12c267c6-0d03-41ae-bea3-7c051c6bff0f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving imagen 2.csv to imagen 2.csv

# %%
df = pd.read_csv("imagen 2.csv", header = None)

# %%
matriz = np.matrix(df)

# %%
plt.gray()
plt.imshow(matriz)

# %%
matriz2 = matriz.compress([False, True, True], axis = 0 )

# %%
plt.imshow(matriz2)
