# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianValencia08/ProyectoDatosAlgoritmos/blob/main/vaca3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# %%
uploades = files.upload()
# Out:
#      <input type="file" id="files-3c14fc27-6d07-4404-a3e7-bc486609a906" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c14fc27-6d07-4404-a3e7-bc486609a906">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving imagen 3.csv to imagen 3.csv

# %%
df = pd.read_csv("imagen 3.csv", header = None)

# %%
matriz = np.matrix(df)

# %%
plt.gray()
plt.imshow(matriz)

# %%
matriz2 = matriz.compress([False, True, True], axis = 0 )

# %%
plt.imshow(matriz2)
